# %%
import datadotworld as dw

#data handling, model creation/evaluation
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from scipy import stats

#make it so that we only show first 4 decimals for floats
np.set_printoptions(precision=4,suppress=True)

# visualization
# %matplotlib inline
import seaborn as sns

# %%
# Datasets are referenced by their path
dataset_key = 'jgrosz99/nba-player-data-1978-2016'

data_world_base_url = 'https://data.world/'

# %%
# Load dataset (onto the local file system)
dataset_local = dw.load_dataset(dataset_key)  # cached under ~/.dw/cache

# %%
yearly_data = dataset_local.dataframes['nba_season_data']

# %%
yearly_stats = yearly_data

# %%
yearly_data.columns.tolist()
# Out:
# ['year',
#  'tm',
#  'player',
#  'age',
#  'g',
#  'mp',
#  'per',
#  'ts',
#  '3par',
#  'ftr',
#  'orb',
#  'drb',
#  'trb',
#  'ast',
#  'stl',
#  'blk',
#  'tov',
#  'usg',
#  'column_s',
#  'ows',
#  'dws',
#  'ws',
#  'ws_48',
#  'column_x',
#  'obpm',
#  'dbpm',
#  'bpm',
#  'vorp',
#  'ows_48',
#  'dws_48',
#  'shot',
#  'player_id',
#  'team_mar',
#  'team_mp',
#  'team_gm',
#  'year_3par',
#  'team_ts',
#  'tm_usg',
#  'tm_ts_w_o_plyr',
#  'reb_vers',
#  'defense',
#  'val_shot',
#  'offense',
#  'mpg_int',
#  'raw_spm',
#  'min',
#  'raw_contrib',
#  'tm_sum',
#  'tm_adj',
#  'bpm_2',
#  'stderr',
#  'contrib',
#  'vorp_2',
#  'reb_vers_2',
#  'val_shot_2',
#  'offense_2',
#  'defense_2',
#  'mpg',
#  'raw_obpm',
#  'contrib_2',
#  'tm_ortg',
#  'tm_sum_2',
#  'tm_adj_2',
#  'tm_drtg',
#  'obpm_2',
#  'ostderr',
#  'ocontrib',
#  'ovorp',
#  'dbpm_2',
#  'dstderr',
#  'dcontrib',
#  'dvorp',
#  'sum_spm',
#  'min_2',
#  'mpg_2',
#  'rempg',
#  'bpm_3',
#  'contrib_3',
#  'vorp_3',
#  'vorp_gm',
#  'o_bpm',
#  'ocontrib_2',
#  'ovorp_2',
#  'ovorp_gm',
#  'd_bpm',
#  'dcontrib_2',
#  'dvorp_2',
#  'dvorp_gm',
#  'production',
#  'prod_gm',
#  'exp_bpm',
#  'truetalentbpm',
#  'exp_min',
#  'truetalentvorp',
#  'truesalary',
#  'truetimevorp',
#  'adjusted_production',
#  'worp',
#  'o_worp',
#  'd_worp',
#  'adjusted_worp',
#  'estimated_position',
#  'bbref_pos',
#  'age_on_feb_1',
#  'yrs_experience',
#  'height',
#  'weight',
#  'rounded_position',
#  'rounded_age']

# %%
shooting_columns = ['year','tm','player','age','g','mp','per','ts','3par','ftr','usg',]

# %%
yearly_stats[yearly_stats['mp'] > 500][['player', 'year', 'ts']].sort_values(by = 'ts', ascending=False).head()
# Out:
#                player  year     ts
# 16666  Brandan Wright  2015  0.762
# 15500    Chris Wilcox  2013  0.725
# 14738  Tyson Chandler  2012  0.708
# 1325    Artis Gilmore  1982  0.702
# 16320     Kyle Korver  2015  0.699

# %%
Rondo_shooting = yearly_stats[yearly_stats['player'] == "Rajon Rondo"][['year', 'ts']]

# %%
Rondo_shooting = Rondo_shooting.set_index(Rondo_shooting['year'])

# %%
Rondo_shooting = Rondo_shooting.drop(['year'], 1)

# %%
df = pd.DataFrame([[2, 3], [5, 6]], pd.Index([1, 4], name="A"), columns=["B", "C"])

# %%
rookie_data_key = 'https://data.world/exercises/logistic-regression-exercise-1'
rookie_data_set_local = dw.load_dataset(rookie_data_key)

# %%
rookies = rookie_data_set_local.dataframes['nba_logreg']

# %%
pd.set_option('display.max_rowwidth', -1)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-132-4c1a19e0e618> in <module>()
# ----> 1 pd.set_option('display.max_rowwidth', -1)
#
# //anaconda/lib/python3.5/site-packages/pandas/core/config.py in __call__(self, *args, **kwds)
#     221
#     222     def __call__(self, *args, **kwds):
# --> 223         return self.__func__(*args, **kwds)
#     224
#     225     @property
#
# //anaconda/lib/python3.5/site-packages/pandas/core/config.py in _set_option(*args, **kwargs)
#     117
#     118     for k, v in zip(args[::2], args[1::2]):
# --> 119         key = _get_single_key(k, silent)
#     120
#     121         o = _get_registered_option(key)
#
# //anaconda/lib/python3.5/site-packages/pandas/core/config.py in _get_single_key(pat, silent)
#      81         if not silent:
#      82             _warn_if_deprecated(pat)
# ---> 83         raise OptionError('No such keys(s): %r' % pat)
#      84     if len(keys) > 1:
#      85         raise OptionError('Pattern matched multiple keys')
#
# OptionError: "No such keys(s): 'display.max_rowwidth'"

# %%
pd.set_option('display.max_columns', None)

# %%
rookies.sort_values('target_5yrs', ascending=False).tail(100)
# Out:
#                      name  gp   min   pts  fgm   fga    fg  3p_made  3pa  \
# 1022  Joe Crispin          21  7.4   3.8   1.2  3.2   38.2  0.7      1.9
# 1024  Brandon Armstrong    35  5.6   1.8   0.8  2.4   31.8  0.1      0.5
# 998   Justin Anderson      55  11.8  3.8   1.3  3.2   40.6  0.4      1.5
# 231   Anthony Frederick    46  6.8   3.3   1.4  2.7   50.4  0.0      0.1
# 233   Everette Stephens    35  6.0   1.9   0.7  2.1   31.9  0.1      0.3
# 992   Adam Harrington      19  5.8   1.6   0.6  1.9   29.7  0.3      0.7
# 965   Vincent Yarbrough    59  23.4  6.9   2.8  7.3   39.3  0.4      1.3
# 969   Mike Batiste         75  16.6  6.4   2.6  6.2   42.2  0.2      1.1
# 972   Jarell Martin        27  14.1  5.7   2.0  4.3   46.6  0.0      0.1
# 973   Casey Jacobsen       72  15.9  5.1   1.7  4.5   37.3  0.7      2.3
# 977   Sean Lampley         35  13.9  4.8   1.6  3.7   43.4  0.0      0.1
# 978   Chris Jefferies      51  13.1  3.9   1.5  3.8   38.7  0.4      1.1
# 979   Lonny Baxter         55  12.4  4.8   1.7  3.7   46.6  0.0      0.0
# 980   Juaquin Hawkins      58  11.8  2.3   1.0  2.6   38.5  0.2      0.4
# 981   Richaun Holmes       51  13.8  5.6   2.2  4.4   51.4  0.2      0.9
# 983   Marcus Haislip       39  11.3  4.1   1.7  3.9   43.1  0.1      0.3
# 238   Nate Wolters         58  22.6  7.2   2.9  6.7   43.7  0.3      1.1
# 987   Ryan Humphrey        48  9.3   1.9   0.7  2.5   29.2  0.0      0.0
# 989   Tamar Slay           36  7.6   2.6   1.1  2.9   37.9  0.2      0.7
# 990   Qyntel Woods         53  6.3   2.4   1.1  2.2   50.0  0.1      0.2
# 991   Cameron Payne        57  12.2  5.0   2.0  4.9   41.0  0.6      1.9
# 295   Harold Pressley      67  13.6  4.6   2.0  4.7   42.3  0.1      0.4
# 299   Grant Gondrezick     64  13.1  5.5   2.1  4.7   45.0  0.1      0.3
# 772   Devin Booker         76  27.7  13.8  4.8  11.4  42.3  1.3      3.8
# 818   Josh Richardson      52  21.3  6.6   2.4  5.2   45.2  1.0      2.2
# 810   Willie Cauley-Stein  66  21.4  7.0   2.9  5.1   56.3  0.0      0.0
# 812   Adam Morrison        78  29.8  11.8  4.6  12.1  37.6  1.1      3.3
# 344   Dwayne McClain       45  10.2  3.5   1.5  4.0   38.3  0.0      0.2
# 343   Fred Cofield         45  10.4  3.7   1.7  4.1   40.8  0.1      0.3
# 342   Tony Snell           77  16.0  4.5   1.7  4.4   38.4  0.7      2.3
# ...          ...           ..   ...  ...   ...  ...    ...  ...      ...
# 875   Daniel Ewing         66  14.7  3.8   1.5  3.9   38.0  0.3      1.2
# 306   Johnny Rogers        45  10.4  4.2   2.0  4.1   48.6  0.0      0.1
# 333   Nick Calathes        71  16.5  4.9   2.0  4.4   45.7  0.3      0.9
# 304   Keith Smith          42  11.0  3.3   1.4  3.6   38.0  0.1      0.2
# 880   Wayne Simien         43  9.6   3.4   1.3  2.8   48.3  0.0      0.0
# 303   Chris Washburn       35  11.0  3.8   1.6  4.1   39.3  0.0      0.0
# 882   Donell Taylor        51  9.1   2.7   1.0  2.7   39.0  0.1      0.3
# 884   Malcolm Brogdon      32  22.9  8.3   3.2  6.9   46.2  0.9      2.1
# 885   Kevin Burleson       39  8.7   1.8   0.6  2.3   25.0  0.3      1.4
# 301   Mason Plumlee        70  18.2  7.4   2.8  4.3   65.9  0.0      0.0
# 865   T.J. McConnell       81  19.8  6.1   2.7  5.7   47.0  0.4      1.1
# 313   Conner Henry         54  6.0   2.3   0.9  2.5   33.8  0.2      0.8
# 863   Salim Stoudamire     61  20.3  9.7   3.3  8.1   41.5  1.3      3.5
# 314   Patrick Ewing        50  35.4  20.0  7.7  16.3  47.4  0.0      0.1
# 332   Marquese Chriss      34  17.1  7.0   2.7  6.3   42.7  0.6      2.1
# 833   Alexander Johnson    59  12.8  4.4   1.5  2.9   53.8  0.0      0.0
# 834   Cedric Simmons       43  12.4  2.9   1.3  3.1   41.7  0.0      0.0
# 835   Frank Kaminsky       81  21.1  7.5   2.7  6.5   41.0  0.8      2.5
# 838   David Noel           68  11.6  2.7   1.0  2.6   36.7  0.3      0.8
# 842   Josh Boone           61  11.0  4.2   1.6  2.8   57.9  0.0      0.0
# 843   Lynn Greer           41  10.5  4.1   1.5  3.4   43.3  0.4      1.3
# 845   Anthony Brown        29  20.7  4.0   1.3  4.3   31.0  0.7      2.4
# 846   Quincy Douby         42  8.5   2.8   1.1  3.0   38.1  0.3      1.2
# 847   Hassan Adams         61  8.1   2.9   1.2  2.2   55.6  0.0      0.0
# 325   Keith Lee            58  20.6  7.4   3.1  6.6   46.6  0.0      0.2
# 849   Bobby Jones          44  7.6   2.5   1.0  2.1   46.2  0.0      0.2
# 850   Andre Brown          38  7.1   2.4   1.1  1.9   56.8  0.0      0.0
# 322   Cody Zeller          82  17.3  6.0   2.1  4.9   42.6  0.0      0.0
# 857   Larry Nance Jr.      63  20.1  5.5   2.5  4.8   52.7  0.0      0.2
# 0     Brandon Ingram       36  27.4  7.4   2.6  7.6   34.7  0.5      2.1
#
#         3p  ftm  fta    ft  oreb  dreb  reb  ast  stl  blk  tov  target_5yrs
# 1022  38.5  0.6  0.6  92.3  0.1   0.4   0.5  1.2  0.2  0.0  0.5  0.0
# 1024  29.4  0.1  0.3  50.0  0.3   0.2   0.5  0.2  0.2  0.0  0.2  0.0
# 998   26.5  0.8  1.0  80.0  0.3   2.1   2.4  0.5  0.3  0.5  0.4  0.0
# 231   40.0  0.5  0.7  70.6  0.6   0.6   1.1  0.4  0.3  0.1  0.7  0.0
# 233   20.0  0.5  0.6  77.3  0.3   0.3   0.7  1.1  0.3  0.1  0.8  0.0
# 992   35.7  0.2  0.2  75.0  0.1   0.4   0.4  0.6  0.1  0.1  0.1  0.0
# 965   26.9  0.8  1.1  79.0  0.6   2.1   2.7  2.2  1.0  0.6  1.4  0.0
# 969   22.2  0.9  1.2  78.4  1.1   2.3   3.4  0.7  0.6  0.2  0.9  0.0
# 972   0.0   1.7  2.3  72.6  1.4   1.7   3.2  0.6  0.3  0.3  0.7  0.0
# 973   31.5  1.0  1.5  68.6  0.4   0.8   1.2  1.0  0.5  0.1  0.8  0.0
# 977   0.0   1.6  2.3  69.5  0.7   1.6   2.4  0.9  0.2  0.1  0.7  0.0
# 978   33.3  0.6  0.8  67.4  0.3   0.8   1.2  0.4  0.4  0.3  0.9  0.0
# 979   0.0   1.3  1.9  68.0  1.2   1.8   3.0  0.3  0.2  0.4  0.8  0.0
# 980   41.7  0.2  0.3  50.0  0.3   1.1   1.3  0.8  0.5  0.1  0.5  0.0
# 981   18.2  1.0  1.5  68.9  1.2   1.4   2.6  0.6  0.4  0.8  0.6  0.0
# 983   25.0  0.7  1.0  68.4  0.5   0.8   1.4  0.2  0.2  0.5  0.5  0.0
# 238   29.0  1.0  1.6  65.6  0.6   2.0   2.6  3.2  0.6  0.3  1.0  0.0
# 987   0.0   0.5  0.8  59.0  0.7   1.4   2.1  0.2  0.2  0.4  0.5  0.0
# 989   28.0  0.2  0.3  70.0  0.2   0.6   0.9  0.4  0.4  0.1  0.6  0.0
# 990   33.3  0.1  0.4  35.0  0.3   0.7   1.0  0.2  0.3  0.0  0.4  0.0
# 991   32.4  0.3  0.4  79.2  0.2   1.3   1.5  1.9  0.6  0.1  0.8  0.0
# 295   25.0  0.5  0.7  72.9  1.0   1.6   2.6  1.8  0.6  0.3  0.9  0.0
# 299   23.5  1.2  1.7  70.1  0.7   1.0   1.7  1.3  0.4  0.1  0.9  0.0
# 772   34.3  2.8  3.4  84.0  0.4   2.1   2.5  2.6  0.6  0.3  2.1  0.0
# 818   46.1  0.8  1.2  66.7  0.4   1.7   2.1  1.4  0.7  0.5  0.7  0.0
# 810   0.0   1.2  1.9  64.8  2.0   3.3   5.3  0.6  0.7  1.0  0.7  0.0
# 812   33.7  1.5  2.2  71.0  0.7   2.3   2.9  2.1  0.4  0.1  1.7  0.0
# 344   11.1  0.4  0.8  51.4  0.3   0.4   0.7  1.5  0.8  0.1  0.9  0.0
# 343   20.0  0.3  0.4  60.0  0.1   0.9   1.0  1.8  0.4  0.1  1.1  0.0
# 342   32.0  0.4  0.5  75.6  0.2   1.4   1.6  0.9  0.4  0.2  0.6  0.0
# ...    ...  ...  ...   ...  ...   ...   ...  ...  ...  ...  ...  ...
# 875   28.2  0.5  0.7  78.3  0.3   0.9   1.3  1.3  0.6  0.1  0.9  0.0
# 306   0.0   0.2  0.3  60.0  0.7   1.0   1.7  0.6  0.2  0.2  0.4  0.0
# 333   31.1  0.6  1.0  61.1  0.3   1.6   1.9  2.9  0.9  0.1  1.4  0.0
# 304   33.3  0.5  0.7  75.0  0.3   0.5   0.8  1.0  0.6  0.1  0.7  0.0
# 880   0.0   0.7  0.8  88.2  0.9   1.2   2.0  0.2  0.3  0.0  0.6  0.0
# 303   0.0   0.5  1.5  35.3  1.0   1.9   2.9  0.5  0.2  0.2  1.1  0.0
# 882   23.5  0.6  0.8  69.8  0.3   0.7   1.0  0.9  0.6  0.1  0.7  0.0
# 884   44.1  0.9  1.1  85.7  0.4   2.1   2.5  3.6  1.0  0.1  1.5  0.0
# 885   18.5  0.4  0.4  94.1  0.1   0.6   0.7  1.2  0.7  0.1  0.6  0.0
# 301   0.0   1.7  2.8  62.6  1.4   3.0   4.4  0.9  0.7  0.8  1.1  0.0
# 865   34.8  0.3  0.5  63.4  0.5   2.6   3.1  4.5  1.2  0.1  1.7  0.0
# 313   31.0  0.3  0.5  63.0  0.1   0.5   0.6  0.6  0.2  0.0  0.5  0.0
# 863   38.0  1.6  1.8  90.0  0.2   1.7   1.9  1.2  0.4  0.1  1.3  0.0
# 314   0.0   4.5  6.1  73.9  2.5   6.5   9.0  2.0  1.1  2.1  3.4  0.0
# 332   31.0  1.0  1.7  59.6  1.1   2.2   3.3  0.5  0.5  0.5  1.2  0.0
# 833   0.0   1.3  2.0  66.1  0.8   2.2   3.1  0.3  0.4  0.6  0.8  0.0
# 834   0.0   0.4  0.8  48.5  1.0   1.5   2.5  0.3  0.2  0.5  0.5  0.0
# 835   33.7  1.3  1.8  73.0  0.9   3.3   4.1  1.2  0.5  0.5  0.7  0.0
# 838   32.1  0.5  0.6  86.0  0.6   1.2   1.8  1.0  0.4  0.1  0.6  0.0
# 842   0.0   0.9  1.7  54.4  1.0   1.8   2.9  0.2  0.2  0.3  0.5  0.0
# 843   34.6  0.7  0.8  84.4  0.0   0.6   0.7  1.3  0.4  0.0  0.4  0.0
# 845   28.6  0.6  0.7  85.0  0.3   2.1   2.4  0.7  0.5  0.2  0.5  0.0
# 846   24.0  0.3  0.4  73.3  0.3   0.6   0.9  0.4  0.4  0.1  0.4  0.0
# 847   0.0   0.4  0.6  66.7  0.6   0.7   1.3  0.2  0.3  0.1  0.4  0.0
# 325   22.2  1.3  1.7  78.1  2.0   4.1   6.1  1.2  0.5  0.6  1.3  0.0
# 849   11.1  0.5  0.9  56.1  0.5   0.8   1.3  0.4  0.3  0.0  0.4  0.0
# 850   0.0   0.2  0.4  60.0  0.7   1.3   1.9  0.1  0.2  0.1  0.8  0.0
# 322   0.0   1.8  2.4  73.0  1.4   2.9   4.3  1.1  0.5  0.5  1.1  0.0
# 857   10.0  0.5  0.7  68.1  1.6   3.3   5.0  0.7  0.9  0.4  0.7  0.0
# 0     25.0  1.6  2.3  69.9  0.7   3.4   4.1  1.9  0.4  0.4  1.3  0.0
#
# [100 rows x 21 columns]

# %%
br_base_url = "stats.nba.com/stats/"
def create_url(end_module, **kwargs):
    print(end_module)
    for name, value in kwargs.items():
        print( '{0} = {1}'.format(name, value))
#    try:
#        param_string = param_list[0]
#        for in param_list.length:
#            param_string
#    except ValueError:
#        print("parameters must be in a list")

# %%
nba.player.get_player("tim", "duncan")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-670846250d17> in <module>()
# ----> 1 nba.player.get_player("tim", "duncan")
#
# AttributeError: module 'nba_py' has no attribute 'player'
